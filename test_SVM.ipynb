# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = "Data-20241001/Carseats.csv" 
df_car = pd.read_csv(file_path)
df_car
# Out:
#      Unnamed: 0  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0             1        138      73           11         276    120       Bad
# 1             2        111      48           16         260     83      Good
# 2             3        113      35           10         269     80    Medium
# 3             4        117     100            4         466     97    Medium
# 4             5        141      64            3         340    128       Bad
# ..          ...        ...     ...          ...         ...    ...       ...
# 395         396        138     108           17         203    128      Good
# 396         397        139      23            3          37    120    Medium
# 397         398        162      26           12         368    159    Medium
# 398         399        100      79            7         284     95       Bad
# 399         400        134      37            0          27    120      Good
#
#      Age  Education Urban   US High
# ...

# %%
df_oz = pd.read_csv('Data-20241001/ozone_complet.txt', delimiter=';')
df_oz = df_oz.drop("maxO3v", axis=1)

# %%
def train_test_split(data, target):
    n = int(len(data)*0.8)
    train = data[:n]
    test = data[n:]

    X_train = train.drop(target, axis=1)
    Y_train = train[target].copy()
    X_test = test.drop(target,axis=1)
    Y_test = test[target].copy()
    return X_train, Y_train, X_test, Y_test

# %%
X_train, Y_train, X_test, Y_test = train_test_split(df_oz, "maxO3")
X_train.head()
# Out:
#             T6    T9   T12   T15   T18  Ne6  Ne9  Ne12  Ne15  Ne18  ...  \
# 19950401  10.1  11.6  13.3  13.6  12.2  8.0  8.0   8.0   8.0   8.0  ...
# 19950402   9.5   9.4  13.8  17.4  16.3  8.0  8.0   7.0   0.0   0.0  ...
# 19950403   3.6   8.0  16.8  21.5  20.2  4.0  5.0   2.0   2.0   3.0  ...
# 19950404   9.5  10.5  11.4  12.2  11.4  8.0  7.0   7.0   7.0   8.0  ...
# 19950405   9.8  10.8  13.8  14.3  13.3  8.0  7.0   8.0   8.0   7.0  ...
#
#           Vvit6  Vdir9  Vvit9  Vdir12  Vvit12  Vdir15  Vvit15  Vdir18  Vvit18  \
# 19950401    2.0  290.0    4.0   300.0     4.0   340.0     4.0    20.0     4.0
# 19950402    2.0  160.0    2.0   180.0     3.0   110.0     1.0   350.0     2.0
# 19950403    2.0   20.0    2.0   340.0     1.0   170.0     2.0   170.0     3.0
# 19950404    3.0   10.0    4.0   350.0     3.0   350.0     3.0   350.0     4.0
# 19950405    2.0  340.0    2.0   280.0     1.0   320.0     3.0   350.0     4.0
#
#               Vx
# 19950401 -3.4641
# 19950402  0.0000
# ...

# %%
Y_train.head()
# Out:
# 19950401    47.6
# 19950402    56.2
# 19950403    61.8
# 19950404    50.8
# 19950405    59.8
# Name: maxO3, dtype: float64
